# %%
import pandas as pd
import numpy as np
import os
import json
import time
import matplotlib.pyplot as plt

# %%
def mkdir(d):
    if not os.path.isdir(d):
        os.mkdir(d)

# %% [markdown]
# ### CSV Anonamization
#
# Making sure to keep people's information as anonymous as possible is very important. I've already anonamized the user ids, but now let's make sure to anonamize the urls as well.

# %%
url_csv = pd.read_csv('inputs/urls.csv')
url_csv.head()
# Out:
#               user                                                url
# 0  giovannamondavi  https://instagram.fbed1-2.fna.fbcdn.net/vp/40b...
# 1  giovannamondavi  https://instagram.fbed1-2.fna.fbcdn.net/vp/34f...
# 2  giovannamondavi  https://instagram.fbed1-2.fna.fbcdn.net/vp/7f8...
# 3  giovannamondavi  https://instagram.fbed1-2.fna.fbcdn.net/vp/e1a...
# 4  giovannamondavi  https://instagram.fbed1-2.fna.fbcdn.net/vp/305...

# %% [markdown]
# As you can see, the users are anonamized, but the urls are not. The following step is only necessary as I used this code for anonamizing the users as well, so feel free to ignore.

# %%
unique_users = set(url_csv.user)
user_ids = {user: ind for ind, user in enumerate(unique_users)}
user_ids
# Out:
# {'3leanorjane': 29,
#  '__mrks': 55,
#  '_its_me_shlee_': 33,
#  'a_lil_less__': 22,
#  'a_venugopal_99': 109,
#  'ackimtrent': 59,
#  'allie.glushanok': 73,
#  'amdion13': 52,
#  'amy.sharpe23': 93,
#  'angelato__': 107,
#  'apollobalboa': 69,
#  'baileyknecht': 45,
#  'batesy5': 88,
#  'bmo1661': 64,
#  'bradleypriem': 28,
#  'bradygreene': 67,
#  'brief_oberview': 50,
#  'brooke8123': 1,
#  'camilala14': 27,
#  'carolinealmonacid': 53,
#  'cassiejanek': 14,
#  'catherine.m.b': 106,
#  'cgbrownie': 56,
#  'cheechee15': 6,
#  'chriistiineex': 99,
#  'christine_m12': 65,
#  'chubeccas': 102,
#  'comeonchristianeeileen': 110,
#  'curlscoffeenchaos': 51,
#  'danaebucci': 84,
#  'danarochaa': 89,
#  'deltazetaxieta': 90,
#  'djomicinski': 96,
#  'donachakra': 42,
#  'donnald.duck': 4,
#  'dzflyfree': 94,
#  'eileenhk_han': 44,
#  'elkethoms': 98,
#  'emmaggiano': 81,
#  'emmaxkatherine': 0,
#  'eraymond21': 24,
#  'giovannamondavi': 79,
#  'hannahbethmccabe': 11,
#  'harsh_pizza': 39,
#  'helen_elaine': 15,
#  'hiplobonoxa': 57,
#  'hot_wheelzz': 70,
#  'ibeecy': 61,
#  'itssunnyrodrigues': 41,
#  'jillserrano': 74,
#  'jimmybuckets3': 34,
#  'jodorisio5596': 72,
#  'jonletts': 105,
#  'justajode': 43,
#  'k8klepper1': 100,
#  'katharinahrmsn': 18,
#  'katherineahayes': 12,
#  'kayla_hehe': 76,
#  'kel_leav07': 31,
#  'kimberlymanning0504': 104,
#  'klynch1437': 82,
#  'kyletengco': 66,
#  'leahhjaynee519': 8,
#  'lextay2gether': 47,
#  'leylathetatarprincess': 38,
#  'linda_travelog': 95,
#  'livoutloudd': 5,
#  'ljs39': 10,
#  'm_kuczmarski': 26,
#  'madisonmcd': 87,
#  'makenziebrady': 103,
#  'malabramo': 58,
#  'mattdasmitdog': 32,
#  'miagrossman': 108,
#  'miamerrel': 71,
#  'michaeljm17': 23,
#  'msrachel13': 46,
#  'mynampati.s': 36,
#  'nicola324': 85,
#  'notsonaivenow': 111,
#  'parx1050': 21,
#  'pdelisio': 3,
#  'pellakuru': 83,
#  'pescapaxton': 2,
#  'pgiannik': 35,
#  'priyankaketkar': 16,
#  'reillymcgreen': 91,
#  'reshapehealth': 9,
#  'ridingdirtywater': 78,
#  'saraa_t': 7,
#  'sarahbayy_': 25,
#  'savannahmazng': 54,
#  'sdobson17': 101,
#  'sebherforth': 92,
#  'serran0nuts': 48,
#  'shanky.15': 97,
#  'shaunalucibello': 63,
#  'sorarhwang': 80,
#  'steinkatie': 30,
#  'stinafaye13': 37,
#  'swilliams821': 49,
#  'tahazaidi87': 86,
#  'temio_o': 13,
#  'thebethcrawford': 75,
#  'thenatali3': 68,
#  'therealdrkris': 40,
#  'torrezriley': 60,
#  'tpriice': 20,
#  'will_dre_duran': 19,
#  'wwolfie': 17,
#  'zooner7714': 77,
#  'zwkrause': 62}

# %% [markdown]
# Now let's get all the unique urls, and create an id for each.

# %%
unique_urls = set(url_csv.url)
url_ids = {url: ind for ind, url in enumerate(unique_urls)}
# url_ids

# %% [markdown]
# Finally, we map the urls to the new ids.

# %%
url_csv.user = url_csv.user.map(user_ids)
url_csv.url = url_csv.url.map(url_ids)
url_csv.head()
# Out:
#    user    url
# 0    79   8781
# 1    79  13613
# 2    79   8231
# 3    79  11487
# 4    79  13493

# %% [markdown]
# Presto! Let's write this to a csv.

# %%
mkdir('outputs')
url_csv.to_csv("outputs/urls_anonamized.csv", index=False)

# %% [markdown]
# And now, we will create a map from the urls to the users, which will be useful in the future when parsing the json data.

# %%
url_to_user = {row[1]['url']: row[1]['user'] for row in url_csv.iterrows()}

# %% [markdown]
# ### Loading Brands Data

# %%
with open('inputs/brands.json' , 'r') as brand_file:
    #Load each result as a line, remove comma at end as that was a bad idea :)
    results = [line[:-1] for line in brand_file.read().strip().split('\n')]

# %%
json.loads(results[5])
# Out:
# {'brands': [],
#  'errors': [],
#  'image_url': 'https://instagram.fbed1-2.fna.fbcdn.net/vp/691596a30d3e1bc19dd4a594bbfc2f3a/5B75342F/t51.2885-15/e15/10919288_1560484327558302_358999512_n.jpg',
#  'metadata': '',
#  'request_id': '1xh7q2objqjfbiq8at'}

# %% [markdown]
# We how have a list of json string representing a brand result for each image. We want to put this into a dataframe so that we can easily analyze the results. We will now process each JSON string.

# %%
brands = []
for result in results:
    try:
        result = json.loads(result)
        for brand in result['brands']:
            brands.append({'brand': brand['label'], 'category': brand['brand_category_name'], 'user': url_to_user[url_ids[result['image_url']]], 'confidence': brand['confidence']})
    except Exception as e:
        print(e)
        
brands_results = pd.DataFrame(brands)
brands_results.head(20)
# Out:
#                          brand               category  confidence  user
# 0               Boston Red Sox          Sports League         100    79
# 1   Domaine Chandon California    Alcoholic Beverages          98    79
# 2               Boston Red Sox          Sports League          96    79
# 3               Dunkin' Donuts                 Coffee         100    79
# 4            Toronto Blue Jays          Sports League         100    12
# 5         New England Patriots          Sports League         100    98
# 6                 Warner Bros.                 Movies         100    98
# 7            NBC International  Media (communication)         100    98
# 8                         Ford            Automobiles         100    98
# 9      Northeastern University              Education         100    98
# 10     Northeastern University              Education          98    98
# 11     Northeastern University              Education          99    59
# 12     Northeastern University              Education          93    59
# 13     Northeastern University              Education         100    59
# 14     Northeastern University              Education         100    59
# 15                        Nike        Fitness Apparel         100    59
# 16                      Adidas        Fitness Apparel         100    59
# 17                       Pepsi                   Soda         100    98
# 18                   Coca Cola                   Soda          92    59
# 19                        Nike        Fitness Apparel         100    59

# %% [markdown]
# Finally, let's write this result to a csv for safekeeping.

# %%
brands_results.to_csv("inputs/brands_full.csv", index=False)

# %% [markdown]
# ### Loading Humans Data

# %%
with open('inputs/humans.json' , 'r') as human_file:
    #Load each result as a line, remove comma at end as that was a bad idea :)
    humans_json = [line[:-1] for line in human_file.read().strip().split('\n')]

# %%
json.loads(humans_json[11])
# Out:
# {'errors': [],
#  'humans': [{'age': '20-29',
#    'ethnicity': 'white',
#    'ethnicity_confidence': 90,
#    'gender': 'female',
#    'gender_confidence': 80,
#    'human_confidence': 99,
#    'tag_location': [24, 24, 15, 15]},
#   {'age': '30-39',
#    'ethnicity': 'white',
#    'ethnicity_confidence': 99,
#    'gender': 'female',
#    'gender_confidence': 99,
#    'human_confidence': 98,
#    'tag_location': [55, 27, 14, 14]}],
#  'image_url': 'https://instagram.fbed1-2.fna.fbcdn.net/vp/2b7c56868c85d2e04576a1d50c765da4/5B49F7E4/t51.2885-15/e15/11351595_115272352140990_1350898472_n.jpg',
#  'metadata': '',
#  'request_id': '1xh7q2objqjfbiq7wr'}

# %% [markdown]
# We now have the humans data in json form as well. Again, we will process it so that it is in a data frame.

# %%
humans = []
for result in humans_json:
    try:
        result = json.loads(result)
        for human in result['humans']:
#             print(brand)
            human['url'] = url_ids[result['image_url']]
            human['user'] = url_to_user[human['url']]
            
            humans.append(human)
#             brands_results.append({'brand': brand[]})
    except Exception as e:
        print(e)
        
humans_results = pd.DataFrame(humans)
humans_results.head(20)
# Out:
#       age                  ethnicity  ethnicity_confidence  gender  \
# 0   20-29                      white                    99  female
# 1   20-29                      white                    99  female
# 2   30-39                      white                    80  female
# 3   30-39                      white                    96  female
# 4   20-29                      asian                    84  female
# 5   20-29                      white                    95  female
# 6    0-12                      white                    70  female
# 7   30-39                      white                    81  female
# 8   20-29  black or african american                    39    male
# 9   20-29                      asian                    43  female
# 10  20-29                      white                    97  female
# 11  30-39                      white                    98    male
# 12  30-39                      white                    98  female
# 13  20-29                      white                    95  female
# 14  20-29                      asian                    99  female
# 15  20-29                      asian                    99    male
# 16  30-39                      white                    59  female
# 17  13-19                      white                    98  female
# 18   0-12                      asian                    83  female
# 19  30-39                      white                    94  female
#
#     gender_confidence  human_confidence      tag_location  url  user
# 0                  93                93    [2, 2, 30, 30]   97     2
# 1                  97                76    [74, 51, 7, 5]   14    92
# 2                  99                97  [43, 15, 12, 12]  189    81
# 3                  99                99  [47, 29, 31, 24]   95    29
# 4                  99                99  [57, 23, 10, 10]  182     1
# 5                  87                97  [22, 23, 10, 10]  182     1
# 6                  93                95    [20, 43, 8, 8]  165    70
# 7                  99                91   [35, 30, 10, 8]  138     2
# 8                  99                99    [35, 65, 8, 8]   52    83
# 9                  99                99   [36, 9, 37, 29]  149    43
# 10                 90                99  [54, 52, 12, 12]   91    26
# 11                 99                99  [37, 33, 17, 17]   91    26
# 12                 79                99  [45, 21, 17, 17]  166    72
# 13                 97                86  [34, 24, 15, 15]  166    72
# 14                 99                99  [55, 26, 10, 10]  130    21
# 15                 99                99  [67, 12, 12, 12]  130    21
# 16                 99                99  [17, 27, 10, 10]  130    21
# 17                 99                94  [31, 23, 10, 10]  130    21
# 18                 94                76  [52, 19, 10, 10]  121    44
# 19                 90                91    [61, 42, 4, 6]  112    98

# %% [markdown]
# And again, let's write this to a csv.

# %%
humans_results.to_csv("inputs/humans_full.csv", index=False)

# %% [markdown]
# Only one more left!
#
# ### Loading Context Data

# %%
with open('inputs/context.json' , 'r') as context_file:
    #Load each result as a line, remove comma at end as that was a bad idea :)
    context_json = [line[:-1] for line in context_file.read().strip().split('\n')]

# %%
json.loads(context_json[54])
# Out:
# {'context': [{'confidence': 72, 'label': 'tree'},
#   {'confidence': 59, 'label': 'sky'},
#   {'confidence': 52, 'label': 'evening'},
#   {'confidence': 51, 'label': 'morning'},
#   {'confidence': 41, 'label': 'sunset'},
#   {'confidence': 37, 'label': 'cityscape'}],
#  'context_hierarchy': {'Calendar': {'Time of Day': {'Evening': ['evening',
#      'sunset'],
#     'Morning': ['morning']}},
#   'Infrastructure': {'Real Estate': {'City': ['cityscape']}},
#   'Sciences': {'Flowers, Plants, Trees': {'Tree': ['tree']},
#    'Sky': {'Sky': ['sky']}}},
#  'errors': [],
#  'image_url': 'https://instagram.fbed1-2.fna.fbcdn.net/vp/605f42c5847697368162817417cacebc/5B75AAFB/t51.2885-15/e35/14482100_1320937517948984_107132092273393664_n.jpg',
#  'metadata': '',
#  'request_id': 'jas58r9iqsjfbeju5o'}

# %% [markdown]
# Looks good again! The only issue, is that we want to use the context hierarchy. So, we will have to process the data a little differently this time.

# %%
def deep_in(d, val):
    if val in d:
        return True
    elif type(d) in [dict]:
        return True in [deep_in(v, val) for v in d.values() if type(v) in [list, dict]] + [v == val for v in d.values() if type(v) not in [list, dict]]
    else:
        return False

# %% [markdown]
# `deep_in` is a helper function to determine if a context label is within a hierarchy chain. Now we will use this to ge the second level of the hierarchy for a label.

# %%
def get_second_level(label, harchy):
    for k in harchy:
        if deep_in(harchy[k], label):
            return list(harchy[k].keys())[0]

# %% [markdown]
# Now we can process the data as normal.

# %%
contexts = []
for i, result in enumerate(context_json):
    try:
        result = json.loads(result)
        for context in result['context']:
            second_level = get_second_level(context['label'], result['context_hierarchy'])
            contexts.append({'confidence': context['confidence'], 'label': context['label'], 'second_level': second_level, 'url': url_ids[result['image_url']], 'user': url_to_user[url_ids[result['image_url']]]})
#             brands_results.append({'brand': brand[]})
    except Exception as e:
        print(e)
contexts_results = pd.DataFrame(contexts)
display(contexts_results.head(20))
contexts_results.to_csv('outputs/test_contexts.csv')
# Out:
#     confidence        label         second_level  url  user
# 0           88      glasses  Fashion Accessories   97     2
# 1           80       beauty  Fashion Accessories   97     2
# 2           56        smile               People   97     2
# 3           54  photography                  Art   97     2
# 4           52         girl               People   97     2
# 5           50  vision care  Fashion Accessories   97     2
# 6           92      horizon                  Sky  173    88
# 7           86          sea        Body of Water  173    88
# 8           81        shore        Body of Water  173    88
# 9           77      morning          Time of Day  173    88
# 10          72        coast        Body of Water  173    88
# 11          66         dawn          Time of Day  173    88
# 12          91         dish                 Food  146    10
# 13          88         food                 Food  146    10
# 14          65         meal                 Food  146    10
# 15          63    breakfast                 Food  146    10
# 16          43      produce                 Food  146    10
# 17          31      dessert                 Food  146    10
# 18          99         snow              Weather   32    41
# 19          99       winter              Seasons   32    41

# %% [markdown]
# ### Analyzing the Data

# %% [markdown]
# Now let's load in the full data set, which is anonamized.

# %%
brands_results.brand.value_counts()[0:20]
# Out:
# Bud Light         3
# New Balance       2
# Garmin            1
# Boston Celtics    1
# Neutrogena        1
# Toyota            1
# Boston Bruins     1
# Kate Spade        1
# Adidas            1
# Ben & Jerry's     1
# Name: brand, dtype: int64

# %% [markdown]
# Unsurprisingly, Northeastern is at the top, but there are some other notable brands. The Red Sox and Patriots are local teams, so it's nice to see them among the sample. And considering the popularity of dunks among New Englanders, it's unsurprising to see it. Next let's do the same for brand categories.

# %%
brands_results.category.value_counts()[0:20]
# Out:
# Fitness Apparel          114
# Sports League             88
# Alcoholic Beverages       71
# Education                 68
# Consumer Electronics      41
# Automobiles               38
# Soda                      35
# Sports and Outdoors       28
# Clothing                  22
# Financial Services        20
# Coffee                    18
# Candy                     15
# Personal Care             14
# Media (communication)     13
# Fast Food                 12
# Superhero                 10
# Social Network             9
# Telecommunication          8
# Air Travel                 6
# Luxury Goods               6
# Name: category, dtype: int64

# %% [markdown]
# Based on this, we can likely conclude that Northeastern students are pretty sporty. Also, like most colleges, we like to drink. Now let's get user counts for brands.

# %%
brands_results.head()
user_brands = {user: set() for user in brands_results.user.unique()}
for row in brands_results.iterrows():
    user_brands[row[1]['user']].add(row[1]['brand'])

brand_totals = {brand: 0 for brand in brands_results.brand.unique()}
for user in user_brands:
    for brand in user_brands[user]:
        brand_totals[brand] += 1
brand_out = pd.DataFrame([{'Brand': item[0], 'Count': item[1]} for item in brand_totals.items()])
brand_out.sort_values(by=['Count'], ascending=False)[0:20]
# Out:
#                        Brand  Count
# 6    Northeastern University     34
# 8                       Nike     19
# 7                     Adidas     17
# 9                  Coca Cola     16
# 11            The North Face     13
# 10                      Ford     12
# 0             Boston Red Sox      8
# 41                 Starbucks      8
# 3       New England Patriots      8
# 1             Dunkin' Donuts      8
# 60              Under Armour      7
# 46              Samuel Adams      6
# 104                 Guinness      6
# 57            Delta Airlines      6
# 19           Bank of America      6
# 20                 Bud Light      6
# 133             Ralph Lauren      6
# 56          New York Yankees      5
# 83                     Apple      5
# 26                       NFL      5

# %% [markdown]
# One of the most interesting things to note here is that though there were only 8 pictures of Dunkin Donuts total they were on 8 different accounts. Meanwhile, Nike had 44 total photos, but only 19 total users. This could mean huskies are more passionate about Nike, or that they are just more likely to post about it. Now let's do the same analysis for brand category.

# %%
user_brand_categories = {user: set() for user in brands_results.user.unique()}
for row in brands_results.iterrows():
    user_brand_categories[row[1]['user']].add(row[1]['category'])

brand_category_totals = {brand_category: 0 for brand_category in brands_results.category.unique()}
for user in user_brand_categories:
    for brand_category in user_brand_categories[user]:
        brand_category_totals[brand_category] += 1
category_out = pd.DataFrame([{'Brand_Category': item[0], 'Count': item[1]} for item in brand_category_totals.items()])
category_out.sort_values(by=['Count'], ascending=False)[0:20]
# Out:
#            Brand_Category  Count
# 0           Sports League     43
# 2     Alcoholic Beverages     37
# 5         Fitness Apparel     35
# 4               Education     34
# 7             Automobiles     28
# 14   Consumer Electronics     24
# 8     Sports and Outdoors     21
# 6                    Soda     20
# 1                  Coffee     17
# 19               Clothing     14
# 11     Financial Services     13
# 16                  Candy     11
# 3   Media (communication)     10
# 12              Superhero      9
# 10              Fast Food      9
# 15         Social Network      8
# 24             Air Travel      6
# 13           Luxury Goods      6
# 26      Telecommunication      6
# 34             Condiments      5

# %% [markdown]
# These are interesting, but unsurprising results. All of the top brand categories make sense for college students, with a few exceptions. Now let's check out the context of the images that are posted.

# %%
contexts_results.head(10)
# Out:
#    confidence            label            second_level    url  user
# 0          89       sports car              Automotive  11487    79
# 1          89          vehicle              Automotive  11487    79
# 2          79              car              Automotive  11487    79
# 3          76         supercar              Automotive  11487    79
# 4          32         race car              Automotive  11487    79
# 5          28  performance car              Automotive  11487    79
# 6          91       photograph                     Art   1649    79
# 7          91            image                     Art   1649    79
# 8          48         monument       Roads and Bridges   1649    79
# 9          41           statue  Nonbuilding Structures   1649    79

# %% [markdown]
# Let's look at the most common tags. Of course, this won't necessarily be the most accurate representation of context, as the same types of tags can appear multiple times per image, but it will give us a general idea.

# %%
contexts_results.label.value_counts()[0:20]
# Out:
# people          2764
# person          2234
# image           1262
# art             1189
# photograph      1128
# clothing         998
# sea              941
# food             901
# meal             866
# vacation         784
# social group     734
# brand            721
# sports           703
# tree             699
# photography      692
# vehicle          663
# color            661
# city             637
# team             602
# poster           564
# Name: label, dtype: int64

# %%
contexts_results.second_level.value_counts()[0:20]
# Out:
# People                        8818
# Art                           5824
# Food                          4762
# Family & Relationships        4633
# Color                         4388
# Cities, Towns, & Buildings    3893
# Body of Water                 2826
# Sports                        2822
# Live Events                   2801
# Terrain                       2671
# Wild Animals                  2440
# Fashion Accessories           2127
# Time of Day                   2006
# Flowers, Plants, Trees        1973
# Clothing                      1765
# Roads and Bridges             1668
# Weather                       1534
# Travel                        1495
# Outdoor Recreation            1359
# Nonbuilding Structures        1232
# Name: second_level, dtype: int64

# %% [markdown]
# It seems that huskies are pretty typical instagrammers. They take selfies, food pictures, and art pictures. Let's collapse these 2nd level tags so that multiple in the same photo don't skew results.

# %%
url_to_2ndlvl = {url: set() for url in contexts_results.url.unique()}
for row in contexts_results.iterrows():
    url_to_2ndlvl[row[1]['url']].add(row[1]['second_level'])

second_lvl_to_count = {second_level: 0 for second_level in contexts_results.second_level.unique()} 
for k in url_to_2ndlvl:
    for val in url_to_2ndlvl[k]:
        second_lvl_to_count[val] += 1
second_level_out = pd.DataFrame([{'Second Level': item[0], 'Count': item[1]} for item in second_lvl_to_count.items()])
second_level_out.sort_values(by=['Count'], ascending=False)[0:20]
# Out:
#     Count                Second Level
# 6    4392                      People
# 1    3232                         Art
# 17   1774                       Color
# 27   1443  Cities, Towns, & Buildings
# 10   1213      Family & Relationships
# 11   1210                        Food
# 16   1203                      Sports
# 3    1100      Nonbuilding Structures
# 18   1097                      Travel
# 23   1066                 Live Events
# 21   1050                 Time of Day
# 5     994                    Clothing
# 46    976               Body of Water
# 9     908                     Terrain
# 13    899      Flowers, Plants, Trees
# 32    886                      Retail
# 15    805         Fashion Accessories
# 41    742                   Education
# 20    689          Outdoor Recreation
# 8     681                     Seasons

# %% [markdown]
# The context tags tell us a slightly different story about huskies. Though they do plenty of outdoor activities (Body of Water, Terrain, Flowers, Plants, Trees), the primary focus of their instagram profiles is people. Let's do the same analysis, but filter out any context results of confidence < 40.

# %%
contexts_results_hc = contexts_results[contexts_results.confidence >= 40]
url_to_2ndlvl = {url: set() for url in contexts_results_hc.url.unique()}
for row in contexts_results_hc.iterrows():
    url_to_2ndlvl[row[1]['url']].add(row[1]['second_level'])

second_lvl_to_count = {second_level: 0 for second_level in contexts_results_hc.second_level.unique()} 
for k in url_to_2ndlvl:
    for val in url_to_2ndlvl[k]:
        second_lvl_to_count[val] += 1
second_level_out = pd.DataFrame([{'Second Level': item[0], 'Count': item[1]} for item in second_lvl_to_count.items()])
second_level_out.sort_values(by=['Count'], ascending=False)[0:20]
# Out:
#     Count                Second Level
# 7    2791                      People
# 1    1852                         Art
# 23   1252                       Color
# 22   1134  Cities, Towns, & Buildings
# 8    1007      Family & Relationships
# 15    909                        Food
# 39    826               Body of Water
# 6     789                     Terrain
# 3     763      Nonbuilding Structures
# 17    758                 Time of Day
# 43    747                      Sports
# 12    725                      Travel
# 9     662      Flowers, Plants, Trees
# 11    584         Fashion Accessories
# 21    555                 Live Events
# 5     550                     Seasons
# 18    524                Wild Animals
# 4     514                     Weather
# 26    508                         Sky
# 42    471                    Clothing

# %% [markdown]
# Most of the top results stay the same, but Sports really takes a hit. The Art tag is likely due to a sample bias, as the photos are all from instagram. Now, as people were the top context tag, let's get some more information about what types of people huskies are putting on their social media.
#
# Generally, the ethnicity results are not considered very accurate at the moment, so we will be ignoring those.

# %%
humans_results.head(10)
# Out:
#      age ethnicity  ethnicity_confidence  gender  gender_confidence  \
# 0  20-29     white                    82  female                 99
# 1  20-29     white                    94  female                 90
# 2  30-39     white                    64  female                 90
# 3  30-39     white                    70  female                 98
# 4  30-39     white                    82  female                 98
# 5  30-39     white                    93    male                 99
# 6  40-49     white                    90    male                 93
# 7  30-39     white                    85  female                 98
# 8  30-39     white                    93  female                 98
# 9  30-39     white                    98    male                 99
#
#    human_confidence      tag_location    url  user
# 0                99  [24, 30, 10, 10]   7046    79
# 1                99  [60, 26, 10, 10]   7046    79
# 2                78  [42, 35, 10, 10]   7046    79
# 3                99    [49, 48, 6, 6]   1649    79
# 4                61    [47, 17, 6, 6]  13613    79
# 5                93     [39, 8, 8, 8]   8231    79
# 6                88    [92, 11, 6, 6]   8231    79
# 7                99   [9, 46, 31, 24]   6009    79
# 8                99  [42, 38, 25, 20]   6009    79
# 9                72  [56, 17, 25, 20]   6009    79

# %% [markdown]
# Let's start by getting an idea of the male/female split in the instagram photos.

# %%
print('Male split: {}%'.format(round(sum(humans_results.gender == 'male') / len(humans_results.gender) * 100, 2)))
print('Female split: {}%'.format(round(sum(humans_results.gender == 'female') / len(humans_results.gender) * 100, 2)))
# Out:
# Male split: 32.23%
# Female split: 67.77%

# %% [markdown]
# Interestingly, there are much more pictures of women in the image set than men. This could be due to a bias in the training set, or that huskies post more pictures of women. According to [US News](https://www.usnews.com/best-colleges/northeastern-university-2199), Northeastern's total distribution is 51% women. So, maybe this means women post more pictures of themselves. It would be revealing to compare this distribution to instagram photos in general.
#
# Let's try determining the gender split of the image set by counting the number of images of each gender per user. If there are more images of female than male, we will classify a user as female, and vice versa. For this, we will only consider gender confidence >= 80%.

# %%
humans_results_hgc = humans_results[humans_results.gender_confidence >= 80]
user_to_mf_count = {user: [0,0] for user in humans_results_hgc.user.unique()}
for row in humans_results_hgc.iterrows():
    user_to_mf_count[row[1]['user']][row[1]['gender'] == 'female'] += 1

is_female_list = [count[1] > count[0] for count in user_to_mf_count.values()]
sum(is_female_list)
print('Female split: {}%'.format(round(sum(is_female_list) / len(is_female_list) * 100, 2)))
print('Male split: {}%'.format(round((1 - (sum(is_female_list) / len(is_female_list))) * 100, 2)))
# Out:
# Female split: 68.75%
# Male split: 31.25%

# %% [markdown]
# Though this method is definitely not perfect, it shows that the most likely reason for the gender discrepancy was the distribution of the dataset. This means previous information should be taken with this context, including the brand and context information. Now le'ts check out the ages.

# %%
ages = humans_results.age
X = ages.unique()
Y = [sum(ages ==age)/len(ages) * 100 for age in X]
plt.rcParams["figure.figsize"] = (10,5)
plt.bar(X, Y, width=0.75, color="blue")
plt.ylabel('% of total')
plt.xlabel('Age group')
plt.show()

# %% [markdown]
# This is about the age distribution we would expect, especially on social media.
#
# ### Conclusions
#
# Huskies are an outdoorsy group of people. They are passionate about the local sports teams, and about the popular beers in the area. Further, huskies love the people in their life.
#
# ##### Contact
#
# Oliver Spohngellert
# spohngellert.o@husky.neu.edu

# %%
# Out:
#    user    url
# 0    79   8781
# 1    79  13613
# 2    79   8231
# 3    79  11487
# 4    79  13493
